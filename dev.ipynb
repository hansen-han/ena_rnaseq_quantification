# %%
import requests
import pandas as pd
import json
import subprocess
import os
import urllib.request

# %%
# Helper functions

def delete_file(file_path):
    try:
        # Check if file exists
        if os.path.exists(file_path):
            os.remove(file_path)
            print(f"File {file_path} has been deleted.")
        else:
            print(f"File {file_path} does not exist.")
    except Exception as e:
        print(f"Error occurred while trying to delete the file: {e}")

def download_ftp_file(ftp_url, local_directory):
    # Parse the filename from the FTP URL
    filename = os.path.basename(ftp_url)
    
    # Ensure the local directory exists
    if not os.path.exists(local_directory):
        os.makedirs(local_directory)
    
    # Define the local file path
    local_file_path = os.path.join(local_directory, filename)
    
    # Check if the file already exists
    if os.path.exists(local_file_path):
        print(f"File {local_file_path} already exists. Skipping download.")
    else:
        # Download the file
        print(f"Downloading {filename} to {local_file_path}...")
        urllib.request.urlretrieve(ftp_url, local_file_path)
        print(f"Downloaded {filename} to {local_file_path}")
# Out:
# Downloading SRR8052713_1.fastq.gz to ./downloaded_files/SRR8052713_1.fastq.gz...
# Downloaded SRR8052713_1.fastq.gz to ./downloaded_files/SRR8052713_1.fastq.gz

# %%
import docker

def is_docker_running():
    try:
        client = docker.from_env()
        client.ping()
        print("Docker daemon is running.")
        return True
    except docker.errors.APIError as e:
        print(f"Failed to connect to Docker daemon: {e}")
        return False

# Check if Docker is running
if is_docker_running():
    # Run your Docker-related code here
    pass
else:
    print("Docker is not running or not reachable.")
# Out:
# Docker daemon is running.

# %%
bio_project_id = "PRJNA496323"
r = requests.get("https://www.ebi.ac.uk/ena/portal/api/filereport?result=read_run&accession={bio_project_id}&limit=1000&format=json&fields=study_accession,secondary_study_accession,sample_accession,secondary_sample_accession,experiment_accession,run_accession,submission_accession,tax_id,scientific_name,instrument_platform,instrument_model,library_name,nominal_length,library_layout,library_strategy,library_source,library_selection,read_count,base_count,center_name,first_public,last_updated,experiment_title,study_title,study_alias,experiment_alias,run_alias,fastq_bytes,fastq_md5,fastq_ftp,fastq_aspera,fastq_galaxy,submitted_bytes,submitted_md5,submitted_ftp,submitted_aspera,submitted_galaxy,submitted_format,sra_bytes,sra_md5,sra_ftp,sra_aspera,sra_galaxy,sample_alias,broker_name,sample_title,nominal_sdev,first_created,bam_ftp,bam_bytes,bam_md5".format(bio_project_id = bio_project_id))
response_dict = json.loads(r.text)

ftp_links = []
# get the run accessions
for run in response_dict:
    try:
        ftp_links.append(run['fastq_ftp'])
    except:
        pass
ftp_links
# Out:
# ['ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052709/SRR8052709_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052709/SRR8052709_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052713/SRR8052713_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052713/SRR8052713_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052717/SRR8052717_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052717/SRR8052717_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052720/SRR8052720_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052720/SRR8052720_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052726/SRR8052726_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052726/SRR8052726_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052730/SRR8052730_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052730/SRR8052730_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052731/SRR8052731_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052731/SRR8052731_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052734/SRR8052734_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052734/SRR8052734_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052738/SRR8052738_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052738/SRR8052738_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052742/SRR8052742_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052742/SRR8052742_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052744/SRR8052744_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052744/SRR8052744_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052748/SRR8052748_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052748/SRR8052748_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052750/SRR8052750_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052750/SRR8052750_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052751/SRR8052751_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052751/SRR8052751_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052752/SRR8052752_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052752/SRR8052752_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052754/SRR8052754_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052754/SRR8052754_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052757/SRR8052757_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052757/SRR8052757_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052761/SRR8052761_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052761/SRR8052761_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052762/SRR8052762_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052762/SRR8052762_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052767/SRR8052767_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052767/SRR8052767_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052774/SRR8052774_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052774/SRR8052774_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052779/SRR8052779_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052779/SRR8052779_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052780/SRR8052780_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052780/SRR8052780_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052788/SRR8052788_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052788/SRR8052788_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052793/SRR8052793_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052793/SRR8052793_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052796/SRR8052796_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052796/SRR8052796_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052797/SRR8052797_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052797/SRR8052797_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052799/SRR8052799_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052799/SRR8052799_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052801/SRR8052801_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052801/SRR8052801_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052803/SRR8052803_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052803/SRR8052803_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052805/SRR8052805_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052805/SRR8052805_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052806/SRR8052806_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052806/SRR8052806_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052808/SRR8052808_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052808/SRR8052808_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052813/SRR8052813_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052813/SRR8052813_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052823/SRR8052823_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052823/SRR8052823_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052826/SRR8052826_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052826/SRR8052826_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052831/SRR8052831_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052831/SRR8052831_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052833/SRR8052833_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052833/SRR8052833_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052836/SRR8052836_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052836/SRR8052836_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052839/SRR8052839_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052839/SRR8052839_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052840/SRR8052840_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052840/SRR8052840_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052842/SRR8052842_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052842/SRR8052842_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052845/SRR8052845_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052845/SRR8052845_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052846/SRR8052846_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052846/SRR8052846_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052847/SRR8052847_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052847/SRR8052847_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052851/SRR8052851_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052851/SRR8052851_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052710/SRR8052710_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052710/SRR8052710_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052714/SRR8052714_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052714/SRR8052714_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052715/SRR8052715_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052715/SRR8052715_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052718/SRR8052718_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052718/SRR8052718_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052723/SRR8052723_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052723/SRR8052723_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052724/SRR8052724_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052724/SRR8052724_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052727/SRR8052727_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052727/SRR8052727_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052728/SRR8052728_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052728/SRR8052728_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052729/SRR8052729_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052729/SRR8052729_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052732/SRR8052732_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052732/SRR8052732_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052733/SRR8052733_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052733/SRR8052733_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052735/SRR8052735_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052735/SRR8052735_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052736/SRR8052736_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052736/SRR8052736_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052737/SRR8052737_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052737/SRR8052737_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052743/SRR8052743_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052743/SRR8052743_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052745/SRR8052745_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052745/SRR8052745_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052763/SRR8052763_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052763/SRR8052763_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052764/SRR8052764_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052764/SRR8052764_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052766/SRR8052766_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052766/SRR8052766_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052769/SRR8052769_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052769/SRR8052769_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052770/SRR8052770_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052770/SRR8052770_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052775/SRR8052775_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052775/SRR8052775_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052776/SRR8052776_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052776/SRR8052776_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052777/SRR8052777_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052777/SRR8052777_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052778/SRR8052778_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052778/SRR8052778_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052781/SRR8052781_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052781/SRR8052781_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052783/SRR8052783_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052783/SRR8052783_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052784/SRR8052784_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052784/SRR8052784_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052786/SRR8052786_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052786/SRR8052786_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052789/SRR8052789_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052789/SRR8052789_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052790/SRR8052790_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052790/SRR8052790_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052791/SRR8052791_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052791/SRR8052791_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052792/SRR8052792_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052792/SRR8052792_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052795/SRR8052795_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052795/SRR8052795_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052804/SRR8052804_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052804/SRR8052804_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052807/SRR8052807_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052807/SRR8052807_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052814/SRR8052814_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052814/SRR8052814_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052817/SRR8052817_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052817/SRR8052817_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052818/SRR8052818_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052818/SRR8052818_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052820/SRR8052820_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052820/SRR8052820_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052821/SRR8052821_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052821/SRR8052821_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052822/SRR8052822_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052822/SRR8052822_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052827/SRR8052827_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052827/SRR8052827_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052832/SRR8052832_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052832/SRR8052832_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052838/SRR8052838_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052838/SRR8052838_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052843/SRR8052843_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052843/SRR8052843_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052848/SRR8052848_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052848/SRR8052848_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052849/SRR8052849_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052849/SRR8052849_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052852/SRR8052852_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052852/SRR8052852_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052708/SRR8052708_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052708/SRR8052708_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052711/SRR8052711_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052711/SRR8052711_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052712/SRR8052712_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052712/SRR8052712_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052716/SRR8052716_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052716/SRR8052716_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052719/SRR8052719_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052719/SRR8052719_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052721/SRR8052721_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052721/SRR8052721_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052722/SRR8052722_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052722/SRR8052722_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052725/SRR8052725_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052725/SRR8052725_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052739/SRR8052739_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052739/SRR8052739_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052740/SRR8052740_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052740/SRR8052740_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052741/SRR8052741_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052741/SRR8052741_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052746/SRR8052746_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052746/SRR8052746_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052747/SRR8052747_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052747/SRR8052747_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052749/SRR8052749_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052749/SRR8052749_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052753/SRR8052753_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052753/SRR8052753_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052755/SRR8052755_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052755/SRR8052755_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052756/SRR8052756_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052756/SRR8052756_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052758/SRR8052758_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052758/SRR8052758_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052759/SRR8052759_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052759/SRR8052759_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052760/SRR8052760_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052760/SRR8052760_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052765/SRR8052765_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052765/SRR8052765_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052768/SRR8052768_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052768/SRR8052768_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052771/SRR8052771_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052771/SRR8052771_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052772/SRR8052772_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052772/SRR8052772_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052773/SRR8052773_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052773/SRR8052773_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052782/SRR8052782_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052782/SRR8052782_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052785/SRR8052785_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052785/SRR8052785_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052787/SRR8052787_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052787/SRR8052787_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052794/SRR8052794_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052794/SRR8052794_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052798/SRR8052798_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052798/SRR8052798_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052800/SRR8052800_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052800/SRR8052800_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052802/SRR8052802_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052802/SRR8052802_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052809/SRR8052809_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052809/SRR8052809_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052810/SRR8052810_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052810/SRR8052810_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052811/SRR8052811_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052811/SRR8052811_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052812/SRR8052812_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/002/SRR8052812/SRR8052812_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052815/SRR8052815_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052815/SRR8052815_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052816/SRR8052816_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/006/SRR8052816/SRR8052816_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052819/SRR8052819_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052819/SRR8052819_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052824/SRR8052824_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052824/SRR8052824_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052825/SRR8052825_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052825/SRR8052825_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052828/SRR8052828_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/008/SRR8052828/SRR8052828_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052829/SRR8052829_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/009/SRR8052829/SRR8052829_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052830/SRR8052830_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052830/SRR8052830_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052834/SRR8052834_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052834/SRR8052834_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052835/SRR8052835_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/005/SRR8052835/SRR8052835_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052837/SRR8052837_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/007/SRR8052837/SRR8052837_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052841/SRR8052841_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/001/SRR8052841/SRR8052841_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052844/SRR8052844_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052844/SRR8052844_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052850/SRR8052850_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/000/SRR8052850/SRR8052850_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052853/SRR8052853_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/003/SRR8052853/SRR8052853_2.fastq.gz',
#  'ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052854/SRR8052854_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR805/004/SRR8052854/SRR8052854_2.fastq.gz']

# %%
local_directory = './downloaded_files'
for link_pair in ftp_links[5:6]:
    files = link_pair.split(";")
    for file in files:

        # some files don't have the ftp:// prefix....
        if "ftp://" not in file:
            file = "ftp://" + file
        
        download_ftp_file(file, local_directory)
# Out:
# Downloading SRR8052730_1.fastq.gz to ./downloaded_files/SRR8052730_1.fastq.gz...

# %%
# Download Salmon Docker Image
try:
    # Execute docker pull command
    subprocess.run(['docker', 'pull', 'combinelab/salmon:latest'], check=True)
    print("Docker image 'combinelab/salmon:latest' pulled successfully.")
except subprocess.CalledProcessError as e:
    print(f"Failed to pull Docker image: {e}")

# %%
# Download Human Reference Genome
url = "ftp://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_39/gencode.v39.transcripts.fa.gz"
filename = "gencode.v39.transcripts.fa.gz"

try:
    # Download the file
    urllib.request.urlretrieve(url, filename)
    print(f"File '{filename}' downloaded successfully.")
except Exception as e:
    print(f"Failed to download file: {e}")

# %%
# Build Index

# Get the current working directory
cwd = os.getcwd()

# Define the Docker command
command = [
    "docker", "run", "--rm",
    "-v", f"{cwd}:/workdir",
    "-w", "/workdir",
    "combinelab/salmon:latest",
    "salmon", "index",
    "-t", "gencode.v39.transcripts.fa",
    "-i", "gencode_index_2"
]

# Execute the command
result = subprocess.run(command, capture_output=True, text=True)

# Print the output and error (if any)
print("Output:", result.stdout)
print("Error:", result.stderr)
print("Return Code:", result.returncode)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 19
#       8 command = [
#       9     "docker", "run", "--rm",
#      10     "-v", f"{cwd}:/workdir",
#    (...)
#      15     "-i", "gencode_index_2"
#      16 ]
#      18 # Execute the command
# ---> 19 result = subprocess.run(command, capture_output=True, text=True)
#      21 # Print the output and error (if any)
#      22 print("Output:", result.stdout)
#
# File /opt/anaconda3/envs/datasci10/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File /opt/anaconda3/envs/datasci10/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File /opt/anaconda3/envs/datasci10/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File /opt/anaconda3/envs/datasci10/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
